# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
sns.set(rc={'figure.figsize':(15,10)})

# %%
data=pd.read_excel('new_fds_proj.xlsx')

# %%
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  passanger weather  time gender  age  \
# 0           0             0      Alone   Sunny    14   Male   21
# 1           1             1  Friend(s)   Sunny    10   Male   21
# 2           2             2  Friend(s)   Sunny    10   Male   21
# 3           3             3  Friend(s)   Sunny    10   Male   21
# 4           4             4  Friend(s)   Sunny    14   Male   21
#
#   maritalStatus         education                  occupation  ...  \
# 0        Single  Bachelors degree  Architecture & Engineering  ...
# 1        Single  Bachelors degree  Architecture & Engineering  ...
# 2        Single  Bachelors degree  Architecture & Engineering  ...
# 3        Single  Bachelors degree  Architecture & Engineering  ...
# 4        Single  Bachelors degree  Architecture & Engineering  ...
#
#   CoffeeHouse  CarryAway  RestaurantLessThan20  weather1  weather2  gender1  \
# 0           1          5                     7         0         1        0
# ...

# %%
data.drop('Unnamed: 0',inplace=True,axis=1)

# %%
data.drop('Unnamed: 0.1',inplace=True,axis=1)

# %%
data.rename(columns={'RestaurantLessThan20':'restaurant'})
# Out:
#        passanger weather  time gender  age maritalStatus         education  \
# 0          Alone   Sunny    14   Male   21        Single  Bachelors degree
# 1      Friend(s)   Sunny    10   Male   21        Single  Bachelors degree
# 2      Friend(s)   Sunny    10   Male   21        Single  Bachelors degree
# 3      Friend(s)   Sunny    10   Male   21        Single  Bachelors degree
# 4      Friend(s)   Sunny    14   Male   21        Single  Bachelors degree
# ...          ...     ...   ...    ...  ...           ...               ...
# 12074    Partner   Rainy    18   Male   26        Single  Bachelors degree
# 12075      Alone   Rainy     7   Male   26        Single  Bachelors degree
# 12076      Alone   Snowy     7   Male   26        Single  Bachelors degree
# 12077      Alone   Snowy     7   Male   26        Single  Bachelors degree
# 12078      Alone   Sunny     7   Male   26        Single  Bachelors degree
#
# ...

# %%
x=data[data["passanger_Alone"]==1]

# %%
sns.distplot(x['Bar'])
# Out:
# C:\Users\syamk\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Bar', ylabel='Density'>

# %%
sns.distplot(x['CoffeeHouse'])
# Out:
# C:\Users\syamk\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CoffeeHouse', ylabel='Density'>

# %%
sns.distplot(x['CarryAway'])
# Out:
# C:\Users\syamk\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CarryAway', ylabel='Density'>

# %%
x=data[data['Bar']!=0]

# %%
plt.figure(figsize=(20, 10))
c=sns.color_palette()
sns.catplot(x='passanger',hue="Bar",kind="count", palette=c, height=8, aspect=2, data=x)
plt.title("Bar vs occupation" )
plt.show()
