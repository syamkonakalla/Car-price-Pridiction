# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import DataFrame

# %%
df=pd.read_excel('C:\\Users\\syamk\\Desktop\\5th sem\\Data science\\project\\fds_proj.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0      locationmet otherpersons weather  temperature  currenttime  \
# 0           0  No Urgent Place        Alone   Sunny           55           11
# 1           1  No Urgent Place    Friend(s)   Sunny           80            9
# 2           2  No Urgent Place    Friend(s)   Sunny           80           12
# 3           3  No Urgent Place    Friend(s)   Sunny           80           14
# 4           4  No Urgent Place    Friend(s)   Sunny           80           13
#
#                   coupon expiration  gender  age  ...  occupation  income Bar  \
# 0        Restaurant(<20)         1d  Female   21  ...  Unemployed   40812   0
# 1           Coffee House         2h  Female   21  ...  Unemployed   44198   0
# 2  Carry out & Take away         2h  Female   21  ...  Unemployed   39978   0
# 3           Coffee House         2h  Female   21  ...  Unemployed   48630   0
# 4           Coffee House         1d  Female   21  ...  Unemployed   48583   0
#
# ...

# %%
sns.scatterplot(data=df, x="age", y="Bar")
# Out:
# <AxesSubplot:xlabel='age', ylabel='Bar'>

# %%
sns.catplot( x="age", y="Bar",kind ='violin',data = df,height=8.27, aspect=11.7/8.27)

# %%
sns.scatterplot(data=df, x="age", y="Bar", hue="weather")
# Out:
# <AxesSubplot:xlabel='age', ylabel='Bar'>

# %%
sns.scatterplot(data=df, x="age", y="Bar", hue="weather",style="weather")
# Out:
# <AxesSubplot:xlabel='age', ylabel='Bar'>

# %%
sns.relplot( x="age", y="Bar",kind ='line',data = df)

# %%
plt=sns.catplot( x="age", y="Bar",data = df)

# %%
plt=sns.catplot( x="age", y="Bar",kind="box",data = df)

# %%
plt=sns.catplot( x="age", y="Bar",kind="boxen",data = df)

# %%
from scipy import stats
c=np.random.normal(loc=5,scale=2,size=100)
sns.distplot(c)
# Out:
# C:\Users\syamk\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
b=sns.FacetGrid(df,col="weather")
b.map(plt.hist,"currenttime")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-3502d512dcda> in <module>
#       1 b=sns.FacetGrid(df,col="weather")
# ----> 2 b.map(plt.hist,"currenttime")
#
# AttributeError: 'FacetGrid' object has no attribute 'hist'

# %%
a=sns.load_dataset("iris")
a
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot(x ='age', y='Bar', kind ='line')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
x=list(df["age"][150:450])
ax = sns.distplot(x, rug=True, hist=True)
# Out:
# C:\Users\syamk\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\syamk\anaconda3\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
sns.catplot(x='gender',y='currenttime',data=df,kind='boxen',height=8.27, aspect=11.7/8.27)

# %%
r=[]
for i in df['gender'][10:50]:
    r.append(df['currenttime'])
    
print(r)
# Out:
# [0        11
# 1         9
# 2        12
# 3        14
# 4        13
#          ..
# 12679     9
# 12680     9
# 12681     9
# 12682     9
# 12683    10
# Name: currenttime, Length: 12684, dtype: int64, 0        11
# 1         9
# 2        12
# 3        14
# 4        13
#          ..
# 12679     9
# 12680     9
# 12681     9
# 12682     9
# 12683    10
# Name: currenttime, Length: 12684, dtype: int64, 0        11
# 1         9
# 2        12
# 3        14
# 4        13
#          ..
# 12679     9
# 12680     9
# 12681     9
# 12682     9
# 12683    10
# Name: currenttime, Length: 12684, dtype: int64, 0        11
# 1         9
# 2        12
# 3        14
# 4        13
#          ..
# 12679     9
# 12680     9
# 12681     9
# 12682     9
# 12683    10
# Name: currenttime, Length: 12684, dtype: int64, 0        11
# 1         9
# 2        12
# 3        14
# 4        13
#          ..
# 12679     9
# 12680     9
# 12681     9
# 12682     9
# 12683    10
# ...

# %%
 
l=  df['gender'][10:50]
print(l)
# Out:
# 10    Female
# 11    Female
# 12    Female
# 13    Female
# 14    Female
# 15    Female
# 16    Female
# 17    Female
# 18    Female
# 19    Female
# 20    Female
# 21    Female
# 22      Male
# 23      Male
# 24      Male
# 25      Male
# 26      Male
# 27      Male
# 28      Male
# 29      Male
# 30      Male
# 31      Male
# 32      Male
# 33      Male
# 34      Male
# 35      Male
# 36      Male
# 37      Male
# 38      Male
# 39      Male
# 40      Male
# 41      Male
# 42      Male
# 43      Male
# 44      Male
# 45      Male
# 46      Male
# 47      Male
# 48      Male
# 49      Male
# Name: gender, dtype: object

# %%
l=df[['gender']df['currenttime']=='10'
# Out:
#   File "<ipython-input-77-64010b2c954e>", line 1
#     l=df['gender']df['currenttime']=='10'
#                   ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=(105,100))
r=df.groupby(['currenttime','gender']).agg({'gender':'count'}).plot(kind='bar',)
# Out:
# <AxesSubplot:xlabel='currenttime,gender'>

# %%
r=df.groupby(['currenttime','gender']).agg({'gender':'count'}).plot(kind='line')

# %%
plt.figure(figsize=(60,100))
sns.catplot(x='gender',data=df,hue='currenttime',kind='count',height=20)
plt.show()

# %%
sns.displot(df, x="currenttime", hue="gender")

# %%
sns.displot(df, x="gender", hue="currenttime")
